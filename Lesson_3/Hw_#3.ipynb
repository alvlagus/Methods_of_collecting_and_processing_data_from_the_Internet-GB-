# %% [markdown]
# ## Методы сбора и обработки данных из сети Интернет
# ### Урок 3. Системы управления базами данных MongoDB и SQLite в Python

# %% [markdown]
# 1. Развернуть у себя на компьютере/виртуальной машине/хостинге MongoDB и реализовать функцию, которая будет добавлять только новые вакансии/продукты в вашу базу.
# 2. Написать функцию, которая производит поиск и выводит на экран вакансии с заработной платой больше введённой суммы (необходимо анализировать оба поля зарплаты). Для тех, кто выполнил задание с Росконтролем - напишите запрос для поиска продуктов с рейтингом не ниже введенного или качеством не ниже введенного (то есть цифра вводится одна, а запрос проверяет оба поля)

# %%
#  загружаемые библиотеки
import re
import requests
from bs4 import BeautifulSoup
from pprint import pprint
from pymongo import MongoClient
import datetime
from pycbrf.toolbox import ExchangeRates
from pymongo.errors import DuplicateKeyError as dke

# %%
#  Подключение базы данных MongoDB
client = MongoClient('localhost', 27017)
db = client['vacancy_base']  # database
hh = db.hh  # collection

# %%
# #  Очистка коллекции БД:
# hh.delete_many({})

# %%
#  Переменные
VACANCY_NAME = 'Data scientist'  # название вакансии
REQ = 400000  # Минимальная сумма для фильтрования вакансий (руб.)
base_url = 'https://hh.ru/search/vacancy'
url = 'https://hh.ru/search/vacancy'
headers = {
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/98.0.4758.80 Safari/537.36'
}
params = {
    # 'search_field': 'name',
    # 'search_field': 'company_name',
    # 'search_field': 'description',
    'text': VACANCY_NAME,
    'area': 113,
    'salary': '',
    'currency_code': 'RUR',
    'experience': 'doesNotMatter',
    'order_by': 'relevance',
    'search_period': 0,
    'items_on_page': 20,
    'no_magic': 'true',
    'L_save_area': 'true',
    'page': 0,
    # 'hhtmFrom': 'vacancy_search_list'
}

# %%
# Сбор данных с сайта https://hh.ru
while True:
    response = requests.get(url, headers=headers, params=params)
    if response.ok:
        dom = BeautifulSoup(response.text, 'html.parser')
        vacancy_boxes = dom.find_all('div', {'class': 'vacancy-serp-item'})

        for vacancy_box in vacancy_boxes:
            vacancy_data = {}
            vacancy = vacancy_box.find('a', {'data-qa': 'vacancy-serp__vacancy-title'})
            vacancy_name = vacancy.getText()
            vacancy_link = vacancy.get('href')
            vacancy_address = vacancy_box.find('div', {'class': 'bloko-text bloko-text_no-top-indent'}).getText().split(', ')[0]

            salary = vacancy_box.find('span', {'data-qa': 'vacancy-serp__vacancy-compensation'})
            if salary is None:
                salary_min = None
                salary_max = None
                salary_currency = None
            else:
                salary_str = salary.getText()
                salary_list = salary_str.split(' ')
                regex = r'[\D+\\.]?$'
                if re.search(regex, salary_str):
                    salary_currency = salary_list[-1]
                else:
                    salary_currency = None
                if salary_str.startswith('от'):
                    salary_min = int(salary_list[1].replace('\u202f', ''))
                    salary_max = None
                elif salary_str.startswith('до'):
                    salary_min = None
                    salary_max = int(salary_list[1].replace('\u202f', ''))
                else:
                    salary_min = int(salary_list[0].replace('\u202f', ''))
                    salary_max = int(salary_list[2].replace('\u202f', ''))

            #  Запись документов в словарь:
            doc = {
                'vacancy': vacancy_name,
                'city': vacancy_address,
                'salary_min': salary_min,
                'salary_max': salary_max,
                'salary_currency': salary_currency,
                'vacancy_link': vacancy_link,
                'site': 'https://hh.ru'
            }

            #  Запись документов в БД:
            try:
                hh.update_one(doc, {'$set': doc}, upsert=True)
            except dke:
                print('Duplicate key error collection')

        next_page = dom.find('a', {'data-qa': 'pager-next'})
        params['page'] += 1

    else:
        print(f'Parsing error on page {url}')
        break

# %%
#  Просмотр результата:
for doc in hh.find({}):
    pprint(doc)
print('Documents in collection: ', db.hh.count_documents({}))  # Выводим количество документов в БД
# Out:
# {'_id': ObjectId('621316934860b72ee987a904'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (команда Поиска)',
#  'vacancy_link': 'https://hh.ru/vacancy/46048820?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a906'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик данных (Data scientist)',
#  'vacancy_link': 'https://hh.ru/vacancy/51239177?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a908'),
#  'city': 'Владивосток',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик данных (Data scientist)',
#  'vacancy_link': 'https://hh.ru/vacancy/51239173?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a90a'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 220000,
#  'salary_min': 150000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52625579?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a90c'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Junior Data Scientist (Специалист по анализу данных)',
#  'vacancy_link': 'https://hh.ru/vacancy/52615958?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a90e'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 160000,
#  'salary_min': 130000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по компьютерному зрению (CV) / Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52505890?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a910'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 1800000,
#  'salary_min': 600000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52631700?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a912'),
#  'city': 'Рязань',
#  'salary_currency': 'руб.',
#  'salary_max': 180000,
#  'salary_min': 130000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик данных / Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/49598346?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a914'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Младший аналитик / Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52763528?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a916'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 250000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50736774?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a918'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 320000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/49423067?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a91a'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по машинному обучению / data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52627493?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a91c'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist / Product analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/52276251?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a91e'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52475275?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a920'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 400000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Deep learning developer / Data scientist, remote',
#  'vacancy_link': 'https://hh.ru/vacancy/52252531?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a922'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 300000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51710392?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a924'),
#  'city': 'Новосибирск',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 50000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist / Machine Learning Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/51604518?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a926'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (аналитик данных в области управления персоналом)',
#  'vacancy_link': 'https://hh.ru/vacancy/52264939?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a928'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в Сбер',
#  'vacancy_link': 'https://hh.ru/vacancy/51471424?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316934860b72ee987a92a'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data engineer/ Инженер по данным',
#  'vacancy_link': 'https://hh.ru/vacancy/50138376?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a92e'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 350000,
#  'salary_min': 250000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52624716?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a931'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 350000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50108323?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a933'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist / ML разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/52408263?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a935'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Middle/Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50467275?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a937'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': 400000,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51361307?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a939'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52120886?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a93b'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Analyst / Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51779542?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a93d'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 450000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52624095?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a93f'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'USD',
#  'salary_max': 5000,
#  'salary_min': 4000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist (ASR; TTS)',
#  'vacancy_link': 'https://hh.ru/vacancy/52721900?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a941'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': 220000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Middle/Senior Data Scientist (Recommender Systems)',
#  'vacancy_link': 'https://hh.ru/vacancy/51956595?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a943'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52166953?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a945'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51662880?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a947'),
#  'city': 'Краснодар',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по машинному обучению / data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52627620?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a949'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 400000,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51361306?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a94b'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52563633?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a94d'),
#  'city': 'Краснодар',
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52563634?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a94f'),
#  'city': 'Екатеринбург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в СберМаркет в команду эффективности платформы',
#  'vacancy_link': 'https://hh.ru/vacancy/50883997?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a951'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в СберМаркет в команду эффективности платформы',
#  'vacancy_link': 'https://hh.ru/vacancy/50883995?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a953'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Дата-сайентист / Data Scientist [Computer Vision]',
#  'vacancy_link': 'https://hh.ru/vacancy/52084874?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a955'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist в Поиск и Рекомендации',
#  'vacancy_link': 'https://hh.ru/vacancy/50485023?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a957'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52563632?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a959'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52671576?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a95b'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/47752047?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a95d'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist (Marketing)',
#  'vacancy_link': 'https://hh.ru/vacancy/52687302?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a95f'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (NLP)',
#  'vacancy_link': 'https://hh.ru/vacancy/51960126?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a961'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50706460?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a963'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50584852?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a965'),
#  'city': 'Екатеринбург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в отдел Аудита Информационных Технологий',
#  'vacancy_link': 'https://hh.ru/vacancy/50415900?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a967'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51955855?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a969'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Middle)',
#  'vacancy_link': 'https://hh.ru/vacancy/50630870?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a96b'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist (Python) middle',
#  'vacancy_link': 'https://hh.ru/vacancy/52620794?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a96d'),
#  'city': 'Казань',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Science',
#  'vacancy_link': 'https://hh.ru/vacancy/52687114?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a96f'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Разработчик нейросетевых алгоритмов / Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50751593?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a971'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': 380000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Ведущий Data Scientist / RNA Lead',
#  'vacancy_link': 'https://hh.ru/vacancy/46213657?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a973'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52615646?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a975'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52684511?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a977'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Analyst / Data Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/52634873?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a979'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Junior Data Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/52599718?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a97b'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51650129?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a97f'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Junior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52516890?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a981'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist senior level',
#  'vacancy_link': 'https://hh.ru/vacancy/52555555?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a983'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51263587?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a986'),
#  'city': 'Нижний Новгород',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50236217?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a988'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50369358?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a98a'),
#  'city': 'Екатеринбург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist senior level',
#  'vacancy_link': 'https://hh.ru/vacancy/52555729?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a98d'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 500000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (middle or senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/51330363?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a990'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data engineer (удаленно)',
#  'vacancy_link': 'https://hh.ru/vacancy/52296844?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a994'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик/Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51895906?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a996'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist / Аналитик Data Science',
#  'vacancy_link': 'https://hh.ru/vacancy/48709110?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a99a'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (NLP), Поиск',
#  'vacancy_link': 'https://hh.ru/vacancy/51280088?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a99c'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Research Engineer / Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50996908?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a99e'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Поиск/Товарные рекомендации)',
#  'vacancy_link': 'https://hh.ru/vacancy/52613361?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9a0'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (контроль качества операционных процессов)',
#  'vacancy_link': 'https://hh.ru/vacancy/52335879?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9a3'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 120000,
#  'salary_min': 100000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Системный аналитик/ Data scientist/ IT analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/51656804?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9a5'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data engineer/Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/52029419?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9a7'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 350000,
#  'salary_min': 250000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51437981?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9a9'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist/ Data Analyst',
#  'vacancy_link': 'https://hh.ru/vacancy/52568279?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9ac'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/45570540?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9ae'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Computer Vision)',
#  'vacancy_link': 'https://hh.ru/vacancy/51630792?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9b0'),
#  'city': 'Москва',
#  'salary_currency': 'EUR',
#  'salary_max': None,
#  'salary_min': 3000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Machine Learning Engineer (ML, Infrastructure)',
#  'vacancy_link': 'https://hh.ru/vacancy/48894153?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9b4'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52108340?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9b6'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist, Поиск',
#  'vacancy_link': 'https://hh.ru/vacancy/51804231?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9b8'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51395685?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9ba'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик данных (Data Scientist)',
#  'vacancy_link': 'https://hh.ru/vacancy/51427357?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316964860b72ee987a9bc'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52075170?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9c1'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist (Antifraud)',
#  'vacancy_link': 'https://hh.ru/vacancy/52243388?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9c3'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Группа сервисов вычислительной химии)',
#  'vacancy_link': 'https://hh.ru/vacancy/52618282?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9c5'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data engineer (удаленно)',
#  'vacancy_link': 'https://hh.ru/vacancy/52609839?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9c7'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'NLP Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/49702248?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9c9'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist / Аналитик (эконометрическое моделирование)',
#  'vacancy_link': 'https://hh.ru/vacancy/43822820?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9cb'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в области рекомендательных систем',
#  'vacancy_link': 'https://hh.ru/vacancy/47342740?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9cd'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52075200?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9cf'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Machine Learning Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/52528474?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9d2'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в направление «Ценообразование»',
#  'vacancy_link': 'https://hh.ru/vacancy/51649877?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9d4'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (анализ коммуникаций)',
#  'vacancy_link': 'https://hh.ru/vacancy/52540542?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9d6'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'ML Engineer / Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50449099?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9d8'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 150000,
#  'salary_min': 90000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик данных Big Data (SQL)',
#  'vacancy_link': 'https://hh.ru/vacancy/52222309?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9da'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 300000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52497490?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9dc'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/43183814?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9de'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Analyst / Data scientist (Analytics Team)',
#  'vacancy_link': 'https://hh.ru/vacancy/52120622?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9e0'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Старший менеджер продукта (Big Data)',
#  'vacancy_link': 'https://hh.ru/vacancy/52418846?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9e2'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist (Remote)',
#  'vacancy_link': 'https://hh.ru/vacancy/47609430?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9e4'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Middle/Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/49588659?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9e6'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist middle',
#  'vacancy_link': 'https://hh.ru/vacancy/52015104?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9e8'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 220000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Python Developer (Data Lab Team)',
#  'vacancy_link': 'https://hh.ru/vacancy/52668196?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9ea'),
#  'city': 'Казань',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик/Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52496525?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9ec'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist (проект "Моменты")',
#  'vacancy_link': 'https://hh.ru/vacancy/47095350?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9ee'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик-разработчик / Data scientist (Middle/Senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/48252917?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9f0'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52546883?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9f2'),
#  'city': 'Иннополис',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52591809?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9f4'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (динамическое ценообразование в девелопменте)',
#  'vacancy_link': 'https://hh.ru/vacancy/52591986?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9f6'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist senior level',
#  'vacancy_link': 'https://hh.ru/vacancy/52555631?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9f8'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist / Senior data scientist (Персонализация)',
#  'vacancy_link': 'https://hh.ru/vacancy/47771885?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9fa'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Machine Learning Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/51955428?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9fc'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52623157?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987a9fe'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52466493?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa00'),
#  'city': 'Казань',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist senior level',
#  'vacancy_link': 'https://hh.ru/vacancy/52555819?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa02'),
#  'city': 'Екатеринбург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Junior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52396407?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa04'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist / Product Analyst (Продуктовый аналитик)',
#  'vacancy_link': 'https://hh.ru/vacancy/48880973?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa06'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Science Team Lead',
#  'vacancy_link': 'https://hh.ru/vacancy/50087171?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa08'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist / Менеджер по обработке данных',
#  'vacancy_link': 'https://hh.ru/vacancy/52495963?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa0a'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Product Owner (Market Data)',
#  'vacancy_link': 'https://hh.ru/vacancy/52662565?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169a4860b72ee987aa0c'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52474620?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa10'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/47865356?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa12'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 300000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Lead data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52421169?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa14'),
#  'city': 'Нижний Новгород',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/47498876?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa16'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/48136307?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa19'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Риск-Аналитик (Data scientist)',
#  'vacancy_link': 'https://hh.ru/vacancy/51710019?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa1b'),
#  'city': 'Краснодар',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в команду Navi',
#  'vacancy_link': 'https://hh.ru/vacancy/51188178?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa1d'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist в команду Navi',
#  'vacancy_link': 'https://hh.ru/vacancy/51188176?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa1f'),
#  'city': 'Ростов-на-Дону',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data engineer (удаленно)',
#  'vacancy_link': 'https://hh.ru/vacancy/52296645?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa22'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/52599981?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa24'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 200000,
#  'site': 'https://hh.ru',
#  'vacancy': 'ML Engineer/ Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52346200?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa26'),
#  'city': 'Иркутск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Инженер-программист/ математик (Data Engineer / Data Scientist)',
#  'vacancy_link': 'https://hh.ru/vacancy/52452813?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa28'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Junior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52345073?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa2a'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51390492?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa2e'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/48701267?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa30'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Engineer (Hadoop/Greenplum/Teradata)',
#  'vacancy_link': 'https://hh.ru/vacancy/52568134?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa32'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist Middle/Middle+',
#  'vacancy_link': 'https://hh.ru/vacancy/50766728?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa34'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Quantitative Research Intern',
#  'vacancy_link': 'https://hh.ru/vacancy/49259597?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa36'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Middle data scientist (Рекомендательные системы)',
#  'vacancy_link': 'https://hh.ru/vacancy/46125724?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa38'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 150000,
#  'site': 'https://hh.ru',
#  'vacancy': 'DWH Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/51655295?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa3a'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data scientist (Computer Vision)',
#  'vacancy_link': 'https://hh.ru/vacancy/47357797?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213169b4860b72ee987aa3c'),
# ...
# {'_id': ObjectId('621327b74860b72ee987b7f3'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (compliance)',
#  'vacancy_link': 'https://hh.ru/vacancy/51788892?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b7f5'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist / Аналитик данных',
#  'vacancy_link': 'https://hh.ru/vacancy/49840130?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b7f8'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/51961785?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b7fc'),
#  'city': 'Казань',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по машинному обучению (Data scientist)',
#  'vacancy_link': 'https://hh.ru/vacancy/51981202?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b7fe'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist (Агентство Starlink)',
#  'vacancy_link': 'https://hh.ru/vacancy/51091771?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b803'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Банк)',
#  'vacancy_link': 'https://hh.ru/vacancy/51741086?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b806'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist (скоринговые и ML модели)',
#  'vacancy_link': 'https://hh.ru/vacancy/49040160?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b808'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'IT Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/50183209?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b80a'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'ML Engineer/ Data Scientist (WAF)',
#  'vacancy_link': 'https://hh.ru/vacancy/48285480?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b80d'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (DataUnicorn.Al team)',
#  'vacancy_link': 'https://hh.ru/vacancy/50570429?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327b74860b72ee987b80f'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (NLP)',
#  'vacancy_link': 'https://hh.ru/vacancy/51579289?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327be4860b72ee987b876'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'C#/ .Net Backend Developer with Azure',
#  'vacancy_link': 'https://hh.ru/vacancy/52797425?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d94f8dfe34c300626ce6'),
#  'city': 'Москва',
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': 3500,
#  'site': 'https://hh.ru',
#  'vacancy': 'Python developer',
#  'vacancy_link': 'https://hh.ru/vacancy/52830122?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d94f8dfe34c300626ced'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Старший аналитик / Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52763528?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d94f8dfe34c300626cfb'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 387600,
#  'salary_min': 310100,
#  'site': 'https://hh.ru',
#  'vacancy': 'IT Expert - Data Architect',
#  'vacancy_link': 'https://hh.ru/vacancy/52818313?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9508dfe34c300626d0d'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52834781?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9508dfe34c300626d14'),
#  'city': 'Новосибирск',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52810561?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9508dfe34c300626d1c'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Analyst / Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52813146?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9518dfe34c300626d36'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist NLP Core',
#  'vacancy_link': 'https://hh.ru/vacancy/52839181?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9518dfe34c300626d38'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Центр валидации моделей сервисных блоков и '
#             'экосистемы)',
#  'vacancy_link': 'https://hh.ru/vacancy/52801201?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9558dfe34c300626d48'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Middle Data scientist (Отдел исследования данных, SberData)',
#  'vacancy_link': 'https://hh.ru/vacancy/47567273?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9558dfe34c300626d4e'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (Направление разработки моделей оценки кредитных '
#             'рисков)',
#  'vacancy_link': 'https://hh.ru/vacancy/52801225?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9558dfe34c300626d5e'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52815892?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9568dfe34c300626d70'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Engineer / Python Developer',
#  'vacancy_link': 'https://hh.ru/vacancy/52837500?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9578dfe34c300626d88'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Lead Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/49642907?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9578dfe34c300626d90'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/49274814?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9578dfe34c300626d9e'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Lead Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/48420232?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9578dfe34c300626da0'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Директор (Data scientist) Управления модельных рисков и валидации',
#  'vacancy_link': 'https://hh.ru/vacancy/52178650?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9578dfe34c300626da7'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 250000,
#  'salary_min': 160000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Разработчик Oracle BI',
#  'vacancy_link': 'https://hh.ru/vacancy/50746642?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9588dfe34c300626db6'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Engineer',
#  'vacancy_link': 'https://hh.ru/vacancy/52816763?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9588dfe34c300626dba'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52480114?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f32'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Python разработчик',
#  'vacancy_link': 'https://hh.ru/vacancy/52809349?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f34'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Инженер данных / DE (удалённо)',
#  'vacancy_link': 'https://hh.ru/vacancy/52818619?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f39'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик (страховые риски)',
#  'vacancy_link': 'https://hh.ru/vacancy/52845142?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f3b'),
#  'city': 'Екатеринбург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Ведущий аналитик',
#  'vacancy_link': 'https://hh.ru/vacancy/52832959?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f3e'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Системный аналитик (Сбер)',
#  'vacancy_link': 'https://hh.ru/vacancy/52846903?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f40'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Портфельный управляющий (family office)',
#  'vacancy_link': 'https://hh.ru/vacancy/52836674?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f46'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Team Lead',
#  'vacancy_link': 'https://hh.ru/vacancy/52839917?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9708dfe34c300626f49'),
#  'city': 'Уфа',
#  'salary_currency': 'руб.',
#  'salary_max': None,
#  'salary_min': 30000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Помощник аналитика',
#  'vacancy_link': 'https://hh.ru/vacancy/52839411?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f4b'),
#  'city': 'Москва',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Lead Product Manager (поиск, рекомендательная система)',
#  'vacancy_link': 'https://hh.ru/vacancy/52835988?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f52'),
#  'city': 'Ростов-на-Дону',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по планированию, контролю и менеджменту качества',
#  'vacancy_link': 'https://hh.ru/vacancy/52804698?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f54'),
#  'city': 'Краснодар',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по планированию, контролю и менеджменту качества',
#  'vacancy_link': 'https://hh.ru/vacancy/52804699?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f56'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по планированию, контролю и менеджменту качества',
#  'vacancy_link': 'https://hh.ru/vacancy/52804696?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f58'),
#  'city': 'Саратов',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по планированию, контролю и менеджменту качества',
#  'vacancy_link': 'https://hh.ru/vacancy/52804701?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f5a'),
#  'city': 'Сочи',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по планированию, контролю и менеджменту качества',
#  'vacancy_link': 'https://hh.ru/vacancy/52804700?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9718dfe34c300626f5c'),
#  'city': 'Волгоград',
#  'salary_currency': None,
#  'salary_max': None,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Специалист по планированию, контролю и менеджменту качества',
#  'vacancy_link': 'https://hh.ru/vacancy/52804697?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('6213d9738dfe34c300626fa3'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 150000,
#  'salary_min': 100000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Аналитик по рискам',
#  'vacancy_link': 'https://hh.ru/vacancy/52006384?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# Documents in collection:  717

# %%
#  Данные взяты с сайта https://www.cbr.ru/.
time_now = datetime.datetime.now()
rates = ExchangeRates(time_now)
dollar = float(rates['USD'].value)
euro = float(rates['EUR'].value)

# %%
# Функция для нахождения зарплаты больше заданной
def find_salary(collection, rate: int):
    rate_rur = rate
    rate_usd = rate / dollar
    rate_eur = rate / euro
    return collection.find({'$or':
        [
            {'salary_currency': 'руб.', '$or': [{'salary_min': {'$gt': rate_rur}}, {'salary_max': {'$gt': rate_rur}}]},
            {'salary_currency': 'USD', '$or': [{'salary_min': {'$gt': rate_usd}}, {'salary_max': {'$gt': rate_usd}}]},
            {'salary_currency': 'EUR', '$or': [{'salary_min': {'$gt': rate_eur}}, {'salary_max': {'$gt': rate_eur}}]}
        ]
    })

# %%
# Вывод вакансий по условию:

res = find_salary(db.hh, rate=REQ)
for doc in res:
    pprint(doc)
# Out:
# {'_id': ObjectId('621316934860b72ee987a910'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 1800000,
#  'salary_min': 600000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52631700?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a93d'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 450000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/52624095?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316944860b72ee987a93f'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'USD',
#  'salary_max': 5000,
#  'salary_min': 4000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Data Scientist (ASR; TTS)',
#  'vacancy_link': 'https://hh.ru/vacancy/52721900?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316954860b72ee987a98d'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 500000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Scientist (middle or senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/51330363?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316a14860b72ee987aab7'),
#  'city': 'Санкт-Петербург',
#  'salary_currency': 'руб.',
#  'salary_max': 500000,
#  'salary_min': 260000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Python Software Engineer (Middle, Senior, Lead)',
#  'vacancy_link': 'https://hh.ru/vacancy/52047343?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316ac4860b72ee987aca0'),
#  'city': 'Москва',
#  'salary_currency': 'USD',
#  'salary_max': 8000,
#  'salary_min': 6000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Python Developer (MLOps tool + OpenSource / US-startup)',
#  'vacancy_link': 'https://hh.ru/vacancy/51906037?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316b14860b72ee987ad1d'),
#  'city': 'Москва',
#  'salary_currency': 'USD',
#  'salary_max': None,
#  'salary_min': 5000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Senior Software Engineer with Proficiency in Algorithms and Math',
#  'vacancy_link': 'https://hh.ru/vacancy/52528513?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621316b14860b72ee987ad1f'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 492817,
#  'salary_min': 379088,
#  'site': 'https://hh.ru',
#  'vacancy': 'IT Solution/System Architect',
#  'vacancy_link': 'https://hh.ru/vacancy/52211023?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327a64860b72ee987b698'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 500000,
#  'salary_min': None,
#  'site': 'https://hh.ru',
#  'vacancy': 'Lead Data Scientist',
#  'vacancy_link': 'https://hh.ru/vacancy/42493107?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327a64860b72ee987b6a3'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 500000,
#  'salary_min': 350000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Data Engineer (Senior)',
#  'vacancy_link': 'https://hh.ru/vacancy/51361166?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
# {'_id': ObjectId('621327a94860b72ee987b6ff'),
#  'city': 'Москва',
#  'salary_currency': 'руб.',
#  'salary_max': 500000,
#  'salary_min': 260000,
#  'site': 'https://hh.ru',
#  'vacancy': 'Python Software Engineer (Middle, Senior, Lead)',
#  'vacancy_link': 'https://hh.ru/vacancy/52047342?from=vacancy_search_list&hhtmFrom=vacancy_search_list&query=Data%20scientist'}
